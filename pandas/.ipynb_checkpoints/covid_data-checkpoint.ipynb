# %%
import pandas as pd
import numpy as np

# %%
url = "https://www.busan.go.kr/covid19/Corona19.do"

# %%
data = pd.read_html(url)

# %%
len(data)
# Out:
# 4

# %%
data[3]
# Out:
#     시도   시구군  장소유형          상호명  \
# 0   부산    북구   음식점        경동영양탕
# 1   부산   사상구   음식점        하동재첩국
# 2   부산    중구   pc방   쓰리팝pc cafe
# 3   부산  부산진구   목욕탕      백천탕(남탕)
# 4   부산   사하구    택시          NaN
# ..  ..   ...   ...          ...
# 57  부산   NaN    택시          NaN
# 58  부산  부산진구  단란주점       태양노래주점
# 59  부산  부산진구    택시           택시
# 60  부산   기장군   미용실         쉬즈헤어
# 61  부산   사하구    기타  바른법연구원 사하지사
#
#                                             주소(도로명주소)  \
# 0                              북구 낙동대로 1776번길 72(구포동)
# 1                                사상구 가야대로 290-12(주례동)
# 2                             중구 비프광장로 28, 2층(남포동 5가)
# 3                                      부산진구 동평로95번길 4
# 4   신평시장 인근-> 사하구 선별진료소 앞(하신번영로127) 사하구 선별진료소앞(하신번...
# ..                                                ...
# 57                                  서구 충무동 사거리->서구보건소
# 58                            부산진구 서면문화로 6, 지하1층(부전동)
# 59                              범내골 지하철역 -> 당평초등학교 인근
# ...

# %%
data[3].T
# Out:
#                                             0                          1   \
# 시도                                          부산                         부산
# 시구군                                         북구                        사상구
# 장소유형                                       음식점                        음식점
# 상호명                                      경동영양탕                      하동재첩국
# 주소(도로명주소)               북구 낙동대로 1776번길 72(구포동)       사상구 가야대로 290-12(주례동)
# 노출일시       2021.4.10.(토) 10:59~11:35북구보건소 상담바람  2021.04.13(화) 11:53-12:07
# 소독여부                                      소독완료                       소독완료
#
#                                   2                          3   \
# 시도                                부산                         부산
# 시구군                               중구                       부산진구
# 장소유형                             pc방                        목욕탕
# 상호명                       쓰리팝pc cafe                    백천탕(남탕)
# ...
