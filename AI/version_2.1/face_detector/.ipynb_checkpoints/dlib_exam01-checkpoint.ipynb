# %%
import dlib
#conda install -c conda-forge dlib             #모듈이 없다면 dlib를 설치하세요
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import tensorflow as tf
import numpy as np

# %%
detector = dlib.get_frontal_face_detector() #정면 얼굴검출은 detector만 있어도 가능
sp = dlib.shape_predictor('./models/shape_predictor_5_face_landmarks.dat')

# %%
img = dlib.load_rgb_image('./img/01.jpg')  #사진 불러오기

plt.figure(figsize=(16, 10))
plt.imshow(img)

# %%
#얼굴인식

# %%
img_result = img.copy()  #깊은 복사

dets = detector(img, 1) 

if len(dets) == 0:
    print('cannot find faces!')

fig, ax = plt.subplots(1, figsize=(16, 10))

for det in dets:
    x, y, w, h = det.left(), det.top(), det.width(), det.height()

    rect = patches.Rectangle((x, y), w, h, linewidth=2, edgecolor='r', facecolor='none')
    ax.add_patch(rect)

ax.imshow(img_result)

# %%
#Find Landmarks 5points

# %%
fig, ax = plt.subplots(1, figsize=(16, 10))

objs = dlib.full_object_detections()

for detection in dets:
    s = sp(img, detection)
    objs.append(s)
    
    for point in s.parts():
        circle = patches.Circle((point.x, point.y), radius=3, edgecolor='r', facecolor='r')
        ax.add_patch(circle)

ax.imshow(img_result)

# %%
#얼굴 정렬

# %%
faces = dlib.get_face_chips(img, objs, size=256, padding=0.3)

fig, axes = plt.subplots(1, len(faces)+1, figsize=(20, 16))

axes[0].imshow(img)

for i, face in enumerate(faces):
    axes[i+1].imshow(face)
